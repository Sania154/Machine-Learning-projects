# %%
# ignore warnings 
import warnings
# set the warninig filter to ignore futurewarning 
warnings.simplefilter(action="ignore",category=FutureWarning)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
current_palette1=sns.color_palette()
sns.palplot(current_palette1)
plt.show()

# %%
sns.palplot(sns.color_palette())
plt.show()

# %%
sns.palplot(sns.color_palette("Reds"))
plt.show()

# %%
sns.palplot(sns.color_palette("BrBG",10))
plt.show()

# %%
sns.palplot(sns.color_palette("BrBG",20))
plt.show()

# %%
sns.palplot(sns.color_palette("colorblind"))
plt.show()

# %% [markdown]
# # Displot

# %%
sns.histplot(df['parch'],kde=False)
plt.show()

# %%
sns.displot(df['age'],)
plt.show()

# %%
sns.displot(df['age'],kind="kde")
plt.show()

# %%
sns.displot(df['age'],kind="ecdf")
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.displot(df['age'],kde=True)
plt.show()

# %% [markdown]
# #  2# Relational plots

# %% [markdown]
# # relplot()

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.relplot(x='age',y='fare',col='pclass',data=df,hue='sex',style='sex',kind='line')
plt.show()

# %% [markdown]
# # scatter plot

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(x='age',y='fare',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3 categorical plot

# %% [markdown]
# # 3.1 Barplot

# %%
plt.figure(figsize=(8,8))
sns.barplot(x='sex',y='survived',hue='pclass',data=df)
plt.show()

# %% [markdown]
# # 3.2 stripplot

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x='sex',y='age',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3.3 Swarmplot

# %%
plt.figure(figsize=(8,8))
sns.swarmplot(x='sex',y='age',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3.4 Boxplot

# %%
plt.figure(figsize=(8,8))
sns.boxplot(y='age',x='survived',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.boxplot(y='age',x='survived',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3.5 Violinplot

# %%
plt.figure(figsize=(8,8))
sns.violinplot(y='age',x='survived',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3.6 Countplot

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='survived',data=df)
plt.show()

# %%
plt.figure(figsize=(8,8))
sns.countplot(x='survived',hue='sex',data=df)
plt.show()

# %% [markdown]
# # 3.7 pointplot

# %%
plt.figure(figsize=(8,8))
sns.pointplot(y='survived',x='sex',hue='pclass',data=df)
plt.show()

# %% [markdown]
# # 4 Regression plots

# %% [markdown]
# # 4.1 Implot()

# %%
sns.lmplot(x='age', y='fare', data=df)
plt.show()
# not best correlation

# %% [markdown]
# # 4.2 Regplot

# %%
sns.regplot(x='fare', y='fare', data=df)
plt.show()
#strong correlation

# %% [markdown]
# # 5 Matrix plots

# %% [markdown]
# # 5.1 Heatmap

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),cmap='coolwarm',annot=True,fmt='2f')
plt.show()

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(df.corr(),cmap='YlGnBu',annot=True,fmt='.2f')
plt.show()
